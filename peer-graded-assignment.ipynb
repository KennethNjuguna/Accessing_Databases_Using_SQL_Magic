# %% [markdown]
# <a href="https://www.kaggle.com/code/kennethnjuguna/peer-graded-assignment?scriptVersionId=147033874" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
